# %% [markdown]
# <style>
# .jp-Notebook,
# .jp-NotebookPanel-notebook {
#     max-width: 85% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     padding-left: 0 !important;
#     padding-right: 0 !important;
# }
# </style>

# %% [markdown]
# ![Logo](./img/logo.png)

# %% [markdown]
# # Markdown (I)

# %% [markdown]
# ## ¿Qué es?
# Lenguaje de marcado que nos permite aplicar formato a nuestros textos mediante unos caracteres especiales (marcas o indicadores). Este lenguaje está pensado para Web, pero es muy común utilizarlo en cualquier tipo de texto, independientemente de su destino.
#
# Lo bueno que tiene es que se edita en **texto plano y está integrado en muchísimas herramientas**, como Jupyter Notebooks o RStudio.
#
# ## Markdown vs HTML
# Tenemos un viejo conocido en cuanto a programación web: HTML. Son lenguajes muy diferentes. Con HTML podemos construir un complejo **árbol de tags**, mientras que markdown se desarrolla en texto plano. Por supuesto, las finalidades también son distintas. Ya verás a lo largo de este notebook que ambos lenguajes son perfectamente compatibles.
#
# ## ¿Cómo funciona?
# Contiene una serie de **carcateres especiales** que le dan forma a los textos.
#
# ## ¿De qué nos va a servir?
# En jupyter lo normal será crear celdas con código, pero también tendremos la posibilidad de insertar celdas de markdown, donde podremos poner **imágenes, títulos, enumerar textos, listar, citar y mas!**

# %% [markdown]
# ## 1.Primera celda
# Haz doble clik en esta celda y verás cómo cambia el texto. Significa que estas en el **modo edición** de Markdown.
#
# Haz ctrl+enter o shift+enter para ejecutar la celda (o botón de play arriba). Así abandonamos el modo edición y nuestro texto obtiene el formato que deseábamos.

# %% [markdown]
# # Mis primeros pasos con Markdown...
# ...son muy buenos

# %%
# Esto es un código de Python.
# Va a ser muy útil en el curso acompañar al código de Python, con este tipo de comentarios, para entener cambios o acciones en dicho código. Al usar un solo # al principio, se genera un texto.

# %% [markdown]
# **TIP**: cuando estemos escribiendo markdown, un buen indicador de que los estamos haciendo bien es que **la letra cambia de color o de forma**.

# %% [markdown]
# # Markdown
# ## 2. Cabeceras
# Ya has visto que en el apartaod anterior usábamos dos ## (hashtag) para poner una cabecera. ¿Por qué dos? Cuantos más hashtags, menor es el tamaño del título.

# %% [markdown]
# # Cabecara 1
# ## Cabecera 2

# %% [markdown]
# El tamaño mínimo lo obtenemos con 6 hashtags. Es decir, Tenemos hasta 6 niveles de profundidad para aplicar a los apartados de nuestro notebook.

# %% [markdown]
# # T1
# ## T2
# ### T3
# #### T4
# ##### T5
# ###### T6

# %% [markdown]
# ## 3.HTML
# Markdown nos ofrece la posibilidad de escribir código HTML, dentri de una celda Markdown. Si te manejas bien con HTML y quieres insertar una porción de código de este lenguaje, markdown lo va a interpretar.

# %% [markdown]
# <h1>Header 1</h1>
# <h2>Header 2</h2>
# <h3>Header 3</h3>

# %% [markdown]
# ## 4. Negrita, cursiva
# Paara resaltar texto en negrita tenemos que rodearlo con asteriscos. En el caso en que queramos cursiva, será un único asterisco, y si deseamos combinar negrita con cursiva, son 3 asteriscos.

# %% [markdown]
# **Ejemplo Negrita**
#
# *Ejemplo Cursiva*
#
# ***Ejemplo en Negrita y Cursiva***

# %% [markdown]
# Cuidado con dejar espacios entre los asteriscos y el texto. Es decir, si queremos escribir en negrita, inmediatamente despues de los asteriscos tiene que ir el texto: ** No es negrita **

# %% [markdown]
# ## 5. Citar
# En ocasiones resulta útil poner una citación, o una nota, destacándola con un margen. Esto lo podemos hacer mediante el símbolo mayor que ">"

# %% [markdown]
# >Recuerda la importancia del conocimiento del negocio y del dominio.
# >> Y utulizar atajos de teclado.
