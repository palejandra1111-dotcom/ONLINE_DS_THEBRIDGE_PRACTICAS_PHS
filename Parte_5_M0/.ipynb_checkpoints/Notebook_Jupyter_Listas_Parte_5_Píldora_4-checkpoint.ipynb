# %% [markdown]
# <img src = "../img/logo.png" width = 500><img src = "../img/python-logo.png" width = 250>

# %% [markdown]
# # Python Basics I

# %% [markdown]
# ## Contenidos

# %% [markdown]
# * [Listas](#Listas)

# %% [markdown]
# ## Listas
# [al indice](#Contenidos)
# Se trata de otro de los tipos de datos de Python más usados. Dentro de las colecciones, que veremos más adelante, la lista es la colección que normalmente se le da más uso. **Nos permiten almacenar conjuntos de variables u objetos**, y son elementos de lo más versátiles puesto que podemos almacenar objetos de distintos tipos, modificarlos, eliminarlos, meter listas dentro de listas... Sus dos caractrísticas principales son:
# * **Mutables**: una vez se ha creado la lista, se puede modificar
# * **Ordenada**: Los elementos tienen un cierto orden, lo que nos permite acceder al elemento que queramos teniendo en cuenta tal orden
#
# En cuanto a su sintaxis, cuando declaremos la lista simplemente hay que separar cada elemento con comas, y rodearlo todo con corchetes.

# %%
# Lista de números
numeros = [1, 3, 5, 6]
print(numeros)
print(type(numeros))
# Out:
# [1, 3, 5, 6]
# <class 'list'>

# %%
# Lista de Strings
strings = [" Esto", "es", "una", "lista"]
print(strings)
print(type(strings))
# Out:
# [' Esto', 'es', 'una', 'lista']
# <class 'list'>

# %%
# Lista de booleanos
booleanos = [True, False, not False, True or False, False and False]
print(booleanos)
print(type(booleanos))
# Out:
# [True, False, True, True, False]
# <class 'list'>

# %%
# Lista de tipos mezclados
mix = ["Esto es", 12, -34.5, True, False, "lista"]
print(mix)
print(type(mix))
# Out:
# ['Esto es', 12, -34.5, True, False, 'lista']
# <class 'list'>

# %%
# Listas dentro de listas
listas = ["Gola","12", 23,[23,True,False]]
print(listas)
print(type(listas))
# Out:
# ['Gola', '12', 23, [23, True, False]]
# <class 'list'>

# %%
# para ver longitud de una lista
len(listas)
# Out:
# 4

# %%
len(mix)
# Out:
# 6

# %%
# Concatenar listas
concatenacion = mix + listas
print(concatenacion)
print(type(concatenacion))
# Out:
# ['Esto es', 12, -34.5, True, False, 'lista', 'Gola', '12', 23, [23, True, False]]
# <class 'list'>

# %%
concatenacion_2 = listas + mix 
print(concatenacion_2)
# Out:
# ['Gola', '12', 23, [23, True, False], 'Esto es', 12, -34.5, True, False, 'lista']

# %% [markdown]
# **NOTA**: ¿Ves por qué los decimales en Python siempre van con puntos y no con comas? Con las colecciones el intérprete de Python se volvería loco.
#
# Podemos ver tambien el tipo de la lista

# %%
type(mix)
# Out:
# list

# %% [markdown]
# Calcular la longitud de la misma mediante el método *built-in* ya visto: `len()`

# %%
len(mix)
# Out:
# 6

# %% [markdown]
# Accedemos a los elemenos de la lista mediante corchetes `[]`
#
# **Importante**. El primer elemento es el 0

# %%
lista_ejemplo = ["lista",2,3,"patata","nuevo elemento"]
print(lista_ejemplo[0])
print(lista_ejemplo[-1]) # (-1) va a dar siempre el último elemento de la lista, independientemente de su longitud.
print(lista_ejemplo[-2]) # se puede recorrer la lista para atras con números negativos
print(lista_ejemplo[2])
print(lista_ejemplo[123])
# Out:
# lista
# nuevo elemento
# patata
# 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 6
#       2 print(lista_ejemplo[0])
#       3 print(lista_ejemplo[-1]) # (-1) va a dar siempre el último elemento de la lista, independientemente de su longitud.
#       4 print(lista_ejemplo[-2]) # se puede recorrer la lista para atras con números negativos
#       5 print(lista_ejemplo[2])
# ----> 6 print(lista_ejemplo[123])
#
# IndexError: list index out of range

# %% [markdown]
# ### Metodos en Listas
# Para el tipo de objeto lista, también hay una serie de métodos catacterísticos que nos permiten operar con ellas: añadir valores, quitarlos, indexado, filtrado, etc... En [este enlace](https://www.w3schools.com/python/python_ref_list.asp) puedes encontrar todos los métodos que podrás usar con listas.

# %%
asignaturas = ["Física","Química","Matemáticas","Literatura"]

# Añadir un elemento a una lista (.append)
asignaturas.append("Filosofía")
print(asignaturas)

# Añadir elementos en una posición determinada (.insert("",""))
asignaturas.insert(1,"Educación Físisca")
print(asignaturas)

# Quitar totos los elementos de la lista (clear())
#asignaturas.clear()
#print(asignaturas)

# Quitar un elemento a partir de su índice o posición (.pop(posicion))
asignaturas.pop(1)
print(asignaturas)

# Quitar un elemento por su valor (.remove(nombre del elemento))
asignaturas.remove("Filosofía")
print(asignaturas)

asignaturas.remove("Cine")
# Out:
# ['Física', 'Química', 'Matemáticas', 'Literatura', 'Filosofía']
# ['Física', 'Educación Físisca', 'Química', 'Matemáticas', 'Literatura', 'Filosofía']
# ['Física', 'Química', 'Matemáticas', 'Literatura', 'Filosofía']
# ['Física', 'Química', 'Matemáticas', 'Literatura']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 23
#      19 # Quitar un elemento por su valor (.remove(nombre del elemento))
#      20 asignaturas.remove("Filosofía")
#      21 print(asignaturas)
#      22
# ---> 23 asignaturas.remove("Cine")
#
# ValueError: list.remove(x): x not in list

# %%
# Ordenar la lista (lo hace alfabeticamente)(.sort())
asignaturas.sort()
print(asignaturas)
# Out:
# ['Física', 'Literatura', 'Matemáticas', 'Química']
